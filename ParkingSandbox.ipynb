# %%
import pandas as pd

# %%
df = pd.read_csv("Parking_Violations_Issued_-_Fiscal_Year_2017.csv", nrows=5000000) #10803028 rows
df.head()
# Out:
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      5092469481  GZH7067                 NY        PAS  07/10/2016
# 1      5092451658  GZH7067                 NY        PAS  07/08/2016
# 2      4006265037  FZX9232                 NY        PAS  08/23/2016
# 3      8478629828  66623ME                 NY        COM  06/14/2017
# 4      7868300310  37033JV                 NY        COM  11/21/2016
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0               7              SUBN        TOYOT              V             0
# 1               7              SUBN        TOYOT              V             0
# 2               5              SUBN         FORD              V             0
# 3              47              REFG        MITSU              T         10610
# 4              69              DELV        INTER              T         10510
#
#    ...  Vehicle Color  Unregistered Vehicle?  Vehicle Year  Meter Number  \
# ...

# %%
df.describe()
# Out:
#        Summons Number  Violation Code  Street Code1  Street Code2  \
# count    5.000000e+06    5.000000e+06  5.000000e+06  5.000000e+06
# mean     6.865847e+09    3.474796e+01  2.404350e+04  2.042234e+04
# std      2.297915e+09    1.933175e+01  2.263334e+04  2.193700e+04
# min      1.002888e+09    0.000000e+00  0.000000e+00  0.000000e+00
# 25%      5.093291e+09    2.000000e+01  5.780000e+03  0.000000e+00
# 50%      8.132566e+09    3.600000e+01  1.817000e+04  1.401000e+04
# 75%      8.487170e+09    4.000000e+01  3.553000e+04  3.398000e+04
# max      8.585600e+09    9.900000e+01  9.802000e+04  9.831000e+04
#
#        Street Code3  Vehicle Expiration Date  Violation Location  \
# count  5.000000e+06             5.000000e+06        4.074901e+06
# mean   2.046745e+04             2.471981e+07        5.569408e+01
# std    2.200949e+04             2.610658e+07        3.796317e+01
# min    0.000000e+00             0.000000e+00        1.000000e+00
# ...

# %%
df.dtypes
# Out:
# Summons Number                         int64
# Plate ID                              object
# Registration State                    object
# Plate Type                            object
# Issue Date                            object
# Violation Code                         int64
# Vehicle Body Type                     object
# Vehicle Make                          object
# Issuing Agency                        object
# Street Code1                           int64
# Street Code2                           int64
# Street Code3                           int64
# Vehicle Expiration Date                int64
# Violation Location                   float64
# Violation Precinct                     int64
# Issuer Precinct                        int64
# Issuer Code                            int64
# Issuer Command                        object
# Issuer Squad                          object
# Violation Time                        object
# Time First Observed                   object
# ...

# %%
df.isna().sum()
# Out:
# Summons Number                             0
# Plate ID                                 340
# Registration State                         0
# Plate Type                                 0
# Issue Date                                 0
# Violation Code                             0
# Vehicle Body Type                      19250
# Vehicle Make                           33030
# Issuing Agency                             0
# Street Code1                               0
# Street Code2                               0
# Street Code3                               0
# Vehicle Expiration Date                    0
# Violation Location                    925099
# Violation Precinct                         0
# Issuer Precinct                            0
# Issuer Code                                0
# Issuer Command                        920771
# Issuer Squad                          921216
# Violation Time                            22
# Time First Observed                  4608134
# ...

# %%
null_cols = ((df.isna().sum()/len(df))*100) > 40
df.drop(null_cols[null_cols.values == True].index.tolist(),axis=1,inplace=True)
df.head(10)
# Out:
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      5092469481  GZH7067                 NY        PAS  07/10/2016
# 1      5092451658  GZH7067                 NY        PAS  07/08/2016
# 2      4006265037  FZX9232                 NY        PAS  08/23/2016
# 3      8478629828  66623ME                 NY        COM  06/14/2017
# 4      7868300310  37033JV                 NY        COM  11/21/2016
# 5      5096917368  FZD8593                 NY        PAS  06/13/2017
# 6      1413609545   X20DCM                 NJ        PAS  08/03/2016
# 7      4628525523   326SF9                 MA        PAS  12/21/2016
# 8      4627113330  HCA5464                 NY        OMS  11/21/2016
# 9      4006478550  VAD7274                 VA        PAS  10/05/2016
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0               7              SUBN        TOYOT              V             0
# ...

# %%
df.columns.to_list()
# Out:
# ['Summons Number',
#  'Plate ID',
#  'Registration State',
#  'Plate Type',
#  'Issue Date',
#  'Violation Code',
#  'Vehicle Body Type',
#  'Vehicle Make',
#  'Issuing Agency',
#  'Street Code1',
#  'Street Code2',
#  'Street Code3',
#  'Vehicle Expiration Date',
#  'Violation Location',
#  'Violation Precinct',
#  'Issuer Precinct',
#  'Issuer Code',
#  'Issuer Command',
#  'Issuer Squad',
#  'Violation Time',
#  'Violation County',
#  'Violation In Front Of Or Opposite',
#  'House Number',
#  'Street Name',
#  'Date First Observed',
#  'Law Section',
#  'Sub Division',
#  'Days Parking In Effect    ',
#  'Vehicle Color',
#  'Vehicle Year',
#  'Feet From Curb',
#  'Violation Post Code',
#  'Violation Description']

# %%
diff = df["Violation Location"] - df["Violation Precinct"]
diff.unique()
# Proof that Violation Location and Violation Precinct are identical
# Out:
# array([nan,  0.])

# %%
unwanted_cols = ["Violation Location", "Issuer Precinct", "Issuer Code", "Issuer Command", "Issuer Squad", \
                "Violation In Front Of Or Opposite", "Date First Observed", "Sub Division", "Days Parking In Effect    ", \
                "Feet From Curb", "Violation Post Code"]
df.drop(columns = unwanted_cols, inplace = True)
df.head(20)
# Out:
#     Summons Number  Plate ID Registration State Plate Type  Issue Date  \
# 0       5092469481   GZH7067                 NY        PAS  07/10/2016
# 1       5092451658   GZH7067                 NY        PAS  07/08/2016
# 2       4006265037   FZX9232                 NY        PAS  08/23/2016
# 3       8478629828   66623ME                 NY        COM  06/14/2017
# 4       7868300310   37033JV                 NY        COM  11/21/2016
# 5       5096917368   FZD8593                 NY        PAS  06/13/2017
# 6       1413609545    X20DCM                 NJ        PAS  08/03/2016
# 7       4628525523    326SF9                 MA        PAS  12/21/2016
# 8       4627113330   HCA5464                 NY        OMS  11/21/2016
# 9       4006478550   VAD7274                 VA        PAS  10/05/2016
# 10      1407740258   2513JMG                 NY        COM  01/11/2017
# 11      8009901763   13657MD                 NY        COM  09/27/2016
# ...

# %%
df["Law Section"].value_counts()
# Out:
# 408     4079228
# 1180     638519
# 1111     282251
# 6408          1
# 1040          1
# Name: Law Section, dtype: int64

# %%
df.isna().sum()
# Out:
# Summons Number                   0
# Plate ID                       340
# Registration State               0
# Plate Type                       0
# Issue Date                       0
# Violation Code                   0
# Vehicle Body Type            19250
# Vehicle Make                 33030
# Issuing Agency                   0
# Street Code1                     0
# Street Code2                     0
# Street Code3                     0
# Vehicle Expiration Date          0
# Violation Precinct               0
# Violation Time                  22
# Violation County             17497
# House Number               1024509
# Street Name                   1763
# Law Section                      0
# Vehicle Color                67875
# Vehicle Year                     0
# Violation Description       505005
# dtype: int64

# %%
colors = df["Vehicle Color"]
"WH" in colors.unique()
# Out:
# True

# %%
color_list = colors.to_list()
for i in range(len(color_list)):
    if color_list[i] == "WH":
        color_list[i] = "WHITE"
pd.DataFrame(color_list)
# Out:
#              0
# 0           GY
# 1           GY
# 2           BK
# 3        WHITE
# 4        WHITE
# ...        ...
# 4999995  WHITE
# 4999996  WHITE
# 4999997   GREY
# 4999998     BR
# 4999999  SILVE
#
# [5000000 rows x 1 columns]
