# %%
import pandas as pd

# %%
folder = "data/"
pest_df = pd.read_csv(f"{folder}pesticides.csv")
rain_df = pd.read_csv(f"{folder}rainfall.csv")
temp_df = pd.read_csv(f"{folder}temp.csv")
ytotal_df = pd.read_csv(f"{folder}yield.csv")
ycrops_df = pd.read_csv(f"{folder}yield_df.csv")

# %%
pest_df
# Out:
#               Domain      Area Element                Item  Year  \
# 0     Pesticides Use   Albania     Use  Pesticides (total)  1990
# 1     Pesticides Use   Albania     Use  Pesticides (total)  1991
# 2     Pesticides Use   Albania     Use  Pesticides (total)  1992
# 3     Pesticides Use   Albania     Use  Pesticides (total)  1993
# 4     Pesticides Use   Albania     Use  Pesticides (total)  1994
# ...              ...       ...     ...                 ...   ...
# 4344  Pesticides Use  Zimbabwe     Use  Pesticides (total)  2012
# 4345  Pesticides Use  Zimbabwe     Use  Pesticides (total)  2013
# 4346  Pesticides Use  Zimbabwe     Use  Pesticides (total)  2014
# 4347  Pesticides Use  Zimbabwe     Use  Pesticides (total)  2015
# 4348  Pesticides Use  Zimbabwe     Use  Pesticides (total)  2016
#
#                               Unit    Value
# 0     tonnes of active ingredients   121.00
# 1     tonnes of active ingredients   121.00
# 2     tonnes of active ingredients   121.00
# ...

# %%
rain_df
# Out:
#              Area  Year average_rain_fall_mm_per_year
# 0     Afghanistan  1985                           327
# 1     Afghanistan  1986                           327
# 2     Afghanistan  1987                           327
# 3     Afghanistan  1989                           327
# 4     Afghanistan  1990                           327
# ...           ...   ...                           ...
# 6722     Zimbabwe  2013                           657
# 6723     Zimbabwe  2014                           657
# 6724     Zimbabwe  2015                           657
# 6725     Zimbabwe  2016                           657
# 6726     Zimbabwe  2017                           657
#
# [6727 rows x 3 columns]

# %%
temp_df
# Out:
#        year        country  avg_temp
# 0      1849  Côte D'Ivoire     25.58
# 1      1850  Côte D'Ivoire     25.52
# 2      1851  Côte D'Ivoire     25.67
# 3      1852  Côte D'Ivoire       NaN
# 4      1853  Côte D'Ivoire       NaN
# ...     ...            ...       ...
# 71306  2009         Mexico     21.76
# 71307  2010         Mexico     20.90
# 71308  2011         Mexico     21.55
# 71309  2012         Mexico     21.52
# 71310  2013         Mexico     22.19
#
# [71311 rows x 3 columns]

# %%
ytotal_df
# Out:
#       Domain Code Domain  Area Code         Area  Element Code Element  \
# 0              QC  Crops          2  Afghanistan          5419   Yield
# 1              QC  Crops          2  Afghanistan          5419   Yield
# 2              QC  Crops          2  Afghanistan          5419   Yield
# 3              QC  Crops          2  Afghanistan          5419   Yield
# 4              QC  Crops          2  Afghanistan          5419   Yield
# ...           ...    ...        ...          ...           ...     ...
# 56712          QC  Crops        181     Zimbabwe          5419   Yield
# 56713          QC  Crops        181     Zimbabwe          5419   Yield
# 56714          QC  Crops        181     Zimbabwe          5419   Yield
# 56715          QC  Crops        181     Zimbabwe          5419   Yield
# 56716          QC  Crops        181     Zimbabwe          5419   Yield
#
#        Item Code   Item  Year Code  Year   Unit  Value
# 0             56  Maize       1961  1961  hg/ha  14000
# ...

# %%
ycrops_df
# Out:
#        Unnamed: 0      Area            Item  Year  hg/ha_yield  \
# 0               0   Albania           Maize  1990        36613
# 1               1   Albania        Potatoes  1990        66667
# 2               2   Albania     Rice, paddy  1990        23333
# 3               3   Albania         Sorghum  1990        12500
# 4               4   Albania        Soybeans  1990         7000
# ...           ...       ...             ...   ...          ...
# 28237       28237  Zimbabwe     Rice, paddy  2013        22581
# 28238       28238  Zimbabwe         Sorghum  2013         3066
# 28239       28239  Zimbabwe        Soybeans  2013        13142
# 28240       28240  Zimbabwe  Sweet potatoes  2013        22222
# 28241       28241  Zimbabwe           Wheat  2013        22888
#
#        average_rain_fall_mm_per_year  pesticides_tonnes  avg_temp
# 0                             1485.0             121.00     16.37
# 1                             1485.0             121.00     16.37
# ...

# %%
ytotal_df['Value'].shift(2)
# Out:
# 0            NaN
# 1            NaN
# 2        14000.0
# 3        14000.0
# 4        14260.0
#           ...
# 56712    27681.0
# 56713    26274.0
# 56714    24420.0
# 56715    22888.0
# 56716    21357.0
# Name: Value, Length: 56717, dtype: float64

# %%
ytotal_df.loc[ytotal_df["Area"] == "Afghanistan"]
# Out:
#     Domain Code Domain  Area Code         Area  Element Code Element  \
# 0            QC  Crops          2  Afghanistan          5419   Yield
# 1            QC  Crops          2  Afghanistan          5419   Yield
# 2            QC  Crops          2  Afghanistan          5419   Yield
# 3            QC  Crops          2  Afghanistan          5419   Yield
# 4            QC  Crops          2  Afghanistan          5419   Yield
# ..          ...    ...        ...          ...           ...     ...
# 219          QC  Crops          2  Afghanistan          5419   Yield
# 220          QC  Crops          2  Afghanistan          5419   Yield
# 221          QC  Crops          2  Afghanistan          5419   Yield
# 222          QC  Crops          2  Afghanistan          5419   Yield
# 223          QC  Crops          2  Afghanistan          5419   Yield
#
#      Item Code   Item  Year Code  Year   Unit  Value
# 0           56  Maize       1961  1961  hg/ha  14000
# ...

# %%
pest_df.loc[pest_df["Area"] == "Afghanistan"]
# Out:
# Empty DataFrame
# Columns: [Domain, Area, Element, Item, Year, Unit, Value]
# Index: []

# %%
rain_df.loc[rain_df[" Area"] == "Afghanistan"]
# Out:
#            Area  Year average_rain_fall_mm_per_year
# 0   Afghanistan  1985                           327
# 1   Afghanistan  1986                           327
# 2   Afghanistan  1987                           327
# 3   Afghanistan  1989                           327
# 4   Afghanistan  1990                           327
# 5   Afghanistan  1991                           327
# 6   Afghanistan  1992                           327
# 7   Afghanistan  1993                           327
# 8   Afghanistan  1994                           327
# 9   Afghanistan  1995                           327
# 10  Afghanistan  1996                           327
# 11  Afghanistan  1997                           327
# 12  Afghanistan  1998                           327
# 13  Afghanistan  1999                           327
# 14  Afghanistan  2000                           327
# 15  Afghanistan  2001                           327
# 16  Afghanistan  2002                           327
# ...

# %%
temp_df.loc[temp_df["country"] == "Afghanistan"]
# Out:
#        year      country  avg_temp
# 29523  1833  Afghanistan     13.91
# 29524  1834  Afghanistan     13.91
# 29525  1835  Afghanistan     14.71
# 29526  1836  Afghanistan       NaN
# 29527  1837  Afghanistan     15.47
# ...     ...          ...       ...
# 29699  2009  Afghanistan     15.09
# 29700  2010  Afghanistan     15.68
# 29701  2011  Afghanistan     15.81
# 29702  2012  Afghanistan     14.51
# 29703  2013  Afghanistan     16.21
#
# [181 rows x 3 columns]

# %%
ycrops_df.loc[ycrops_df["Area"] == "Afghanistan"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Area, Item, Year, hg/ha_yield, average_rain_fall_mm_per_year, pesticides_tonnes, avg_temp]
# Index: []

# %%
ycrops_df[ycrops_df["Area"] == "Brazil"].corr()["hg/ha_yield"]
# Out:
# Unnamed: 0                       0.083519
# Year                             0.095886
# hg/ha_yield                      1.000000
# average_rain_fall_mm_per_year         NaN
# pesticides_tonnes                0.072202
# avg_temp                        -0.000016
# Name: hg/ha_yield, dtype: float64

# %%
ycrops_df.

# %%
for country in list(ycrops_df["Area"].unique()):
    print(f'\n {country}')
    print(ycrops_df[ycrops_df["Area"] == country].corr()["hg/ha_yield"])
# Out:
#  Albania
# Unnamed: 0                       0.331752
# Year                             0.345619
# hg/ha_yield                      1.000000
# average_rain_fall_mm_per_year         NaN
# pesticides_tonnes                0.325037
# avg_temp                         0.196935
# Name: hg/ha_yield, dtype: float64
#
#  Algeria
# Unnamed: 0                       0.259793
# Year                             0.274150
# hg/ha_yield                      1.000000
# average_rain_fall_mm_per_year         NaN
# pesticides_tonnes                0.235912
# avg_temp                         0.121683
# Name: hg/ha_yield, dtype: float64
#
#  Angola
# Unnamed: 0                       0.007963
# Year                             0.020174
# hg/ha_yield                      1.000000
# average_rain_fall_mm_per_year         NaN
# pesticides_tonnes                0.022389
# avg_temp                         0.000009
# Name: hg/ha_yield, dtype: float64
#
#  Argentina
# Unnamed: 0                       0.076577
# ...
